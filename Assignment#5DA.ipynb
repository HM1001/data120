# %%
import glob
import numpy as  np
import matplotlib.pyplot as plt
import pandas as pd

df1 = pd.read_csv('data-01.csv')
df2 = pd.read_csv('data-02.csv')
df3 = pd.read_csv('data-03.csv')
df4 = pd.read_csv('data-04.csv')

df2.head()
# Out:
#    0  0.1  0.2  1  3  4  6  5  2  7  ...  6.3  6.4  6.5  6.6  5.3  4.2  2.1  \
# 0  0    0    2  2  4  2  1  7  5  7  ...    3    5    7    7    3    2    2
# 1  0    1    2  3  2  1  4  1  8  7  ...    7    2    5    6    4    5    4
# 2  0    0    0  0  1  2  4  7  3  5  ...    2    3    2    3    5    3    1
# 3  0    1    0  2  1  2  3  6  5  2  ...    9    9    8    5    3    5    3
# 4  0    0    1  3  4  4  2  2  6  3  ...    9    6    4    5    1    4    1
#
#    1.1  1.2  0.3
# 0    0    2    1
# 1    0    2    1
# 2    3    1    1
# 3    0    2    1
# 4    0    0    0
#
# [5 rows x 40 columns]

# %%
#visualize(df1)
#indentify_issues(df1)

def visualize(dataframe):
    col_max = df1.max(axis=0)
    col_min = df1.min(axis=0)
    col_max = df1.mean(axis=0)
    
    fig, (ax1, ax2, ax3 = plt.subplots(nrows=1, ncols=3)
    
    ax1.plot(col_min, lable='maximum')
    ax2.plot(col_max, lable='minimum')
    ax3.plot(col_mean, lable='average')
    
    ax1.legend()
    ax1.set_title('Dataframe')
    ax1.set_xlable('feature')
    ax1.set_ylable('maximum')
          
    ax2.legend()
    ax2.set_title('Dataframe')
    ax2.set_xlable('feature')
    ax2.set_ylable('minimum')
    
    ax3.legend()
    ax3.set_title('Dataframe')
    ax3.set_xlable('feature')
    ax3.set_ylable('Average')
    
    plt.tight_layout()
    
plt.show()

          
          
def identify_issues():
    
    col_max20 = df1['20'].max(axis=0)
    col_max0 = df1['0'].max(axis=0)
    col_min = df1.min(axis=0)
    if(col_max0 == 0):
        if(col_max20 == 20):
            print("i doubt the integrity of this dataset")
    else if(col_min == 0):
        print("why is this happeneing")
        else:
            print("dataset looks good")
